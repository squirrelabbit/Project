# %% [raw]
# # Json / folium / 설치필요합니다 (pip install)

# %%
import pandas as pd # 데이터 전처리시 사용
import numpy as np # 데이터 전처리시 사용
import time
import tqdm # 진행률 확인

import seaborn as sns # 데이터 시각화 
import matplotlib.pyplot as plt # 데이터 시각화
import folium # 데이터 시각화 (지도)
from sklearn.preprocessing import LabelEncoder
import json
import requests

# %%
# 동별 시각화
seoul_path = "C://Users//insoo//Desktop//gangseo//Data/HangJeongDong_ver20220101_gangseo.json" # 강서구 동별 Json
seoul_geo = json.load(open(seoul_path, encoding = "utf-8"))

# %%
seoul_geo
# Out:
# {'type': 'FeatureCollection',
#  'name': 'HangJeongDong_ver20220101',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}},
#  'features': [{'type': 'Feature',
#    'properties': {'OBJECTID': 241,
#     'adm_nm': '서울특별시 강서구 염창동',
#     'adm_cd': '1116051',
#     'adm_cd2': '1150051000',
#     'sgg': '11500',
#     'sido': '11',
#     'sidonm': '서울특별시',
#     'temp': '강서구 염창동',
#     'sggnm': '강서구',
#     'adm_cd8': '11160510'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[126.88316628434919, 37.55446522843518],
#        [126.88975440070294, 37.55017183813918],
#        [126.88661380374252, 37.547459453767566],
#        [126.8852754472667, 37.54630327749581],
#        [126.88572262194404, 37.54431813614695],
#        [126.88577067311726, 37.54423839161363],
#        [126.88616574426541, 37.543596032857415],
#        [126.88515694463443, 37.54358960812174],
#        [126.88324748315515, 37.54555697857488],
# ...

# %%
dongData = pd.read_excel("강서구 1인가구 동별_서울 열린데이터광장_2021(행정구역별 시설 정보포함).xlsx")
dongData.fillna(0)
# Out:
#          행정동    총인구   1인가구  2인 이상   공원  심리상담센터  사회복지시설  정신건강의학과
# 0    강서구 염창동  14685   2993  11692  1.0     4.0       1      0.0
# 1   강서구 등촌1동  11958   6021   5937  1.0     4.0       6      1.0
# 2   강서구 등촌2동   8112   2147   5965  0.0     0.0       3      0.0
# 3   강서구 등촌3동  14168   5335   8833  1.0     6.0      26      1.0
# 4   강서구 화곡본동  15070   5647   9423  1.0     1.0      22      0.0
# 5   강서구 화곡2동   7552   2322   5230  0.0     0.0       5      0.0
# 6   강서구 화곡3동   8378   2282   6096  0.0     1.0       3      1.0
# 7   강서구 화곡4동   8911   2969   5942  0.0     0.0       3      2.0
# 8   강서구 화곡6동  10793   4182   6611  0.0     3.0      13      1.0
# 9   강서구 화곡8동  10639   3346   7293  0.0     1.0       8      1.0
# 10  강서구 가양1동  18538  11023   7515  1.0    12.0       5      6.0
# 11  강서구 가양2동   7529   3623   3906  1.0     2.0      11      1.0
# 12  강서구 가양3동   7457   2925   4532  0.0     0.0       1      0.0
# 13  강서구 발산1동  12733   2152  10581  0.0     4.0      12      5.0
# ...

# %%
seoul = folium.Map(location=[37.5642135, 127.0016985], zoom_start=11, tiles = "cartodbpositron") # 위도 경도 서울 기준

# %%
seoul.choropleth(geo_data=seoul_geo, #Json 파일
                     data = dongData, # 데이터
                     columns = ["행정동","1인가구"], # [데이터셋의 구역(ex 동), 표시할 칼럼]
                     key_on = "feature.properties.temp", # Json 데이터셋의 구역에 해당하는 칼럼
                     legend_name = "1인 가구수", # 지도 우측상단 표기 내용
                     highlight = True, # 강조표시
                     fill_color = "PuRd") # 색상
seoul
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [raw]
# # Marker 연습

# %%
marker = folium.Marker([37.55459659834, 126.83722951069], # 마커의 위도 경도 표시
                  popup = "아무거나",
                  icon = folium.Icon(color="blue"))# 해당 아이콘의 색깔을 지정해준다.

# %%
marker.add_to(seoul)

# %% [raw]
# # 심리상담센터 파일 읽기

# %%
# 심리상담센터 파일 읽기
sim = pd.read_excel("강서구_심리상담선터_위경도추가.xlsx")
sim.head()
# Out:
#    Unnamed: 0         회사명                                     주소         위도  \
# 0           0    건 심리상담센터  서울특별시 강서구 등촌1동 공항대로45길 44 청림오피스텔 712호  37.556778
# 1           1    경연심리상담센터               서울특별시 강서구 강서로27길 42 101호  37.538646
# 2           2  SDU 심리상담센터                서울특별시 강서구 화곡6동 공항대로 424  37.551757
# 3           3    큰사랑심리상담소      서울특별시 강서구 등촌동 698-1 세신등촌종합상가 503호  37.560599
# 4           4  그루터기심리상담센터        서울특별시 강서구 마곡서로 158 센트럴타워2 1307호  37.577349
#
#            경도    행정동
# 0  126.855793  등촌제1동
# 1  126.839627  화곡제1동
# 2  126.850066  화곡제6동
# 3  126.846574  등촌제3동
# 4  126.836775  가양제1동

# %%
# 심리상담센터 위도 / 경도 기반으로 한 위치 Marker 찍기
for i in range(len(sim)):
    marker_sim = folium.Marker([sim.loc[i]["위도"], sim.loc[i]["경도"]],
                              icon = folium.Icon(color = "blue"))
    marker_sim.add_to(seoul)

# %%
seoul
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [raw]
# # googlemaps을 통해 위도, 경도 활용해 주소 찾기

# %%
import googlemaps

# %%
bus = pd.read_excel("C:\\Users\\insoo\\Desktop\\gangseo\\new\\data\\서울시버스정류소좌표데이터(2021.01.14.)_강서구_서울 열린데이터 광장_2021.xlsx")

# %%
bus
# Out:
#           표준ID  ARS-ID            정류소명         X좌표        Y좌표  \
# 0    115000001   16001      염창역.서울도시가스  126.875883  37.547074
# 1    115000002   16002      염창역.서울도시가스  126.875057  37.546863
# 2    115000003   16003       등촌역.강서보건소  126.868670  37.549024
# 3    115000004   16004       등촌역.강서보건소  126.867608  37.549420
# 4    115000005   16005    등촌중학교 백석초등학교  126.861542  37.552610
# ..         ...     ...             ...         ...        ...
# 595  115000571   16993  김포공항세관.국립항공박물관  126.808323  37.555855
# 596  115900146   16994            강원슈퍼  126.857010  37.535532
# 597  115000568   16995          대한항공빌딩  126.814586  37.550747
# 598  115000563   16996            대한항공  126.816540  37.549599
# 599  115000562   16997         김포공항국제선  126.800904  37.564814
#
#                       주소
# 0     대한민국 서울특별시 강서구 염창동
# 1     대한민국 서울특별시 양천구 목2동
# 2     대한민국 서울특별시 양천구 목3동
# 3      대한민국 서울특별시 양천구 목동
# 4     대한민국 서울특별시 강서구 등촌동
# ..                   ...
# 595   대한민국 서울특별시 강서구 공항동
# ...

# %%
google_maps_key = "AIzaSyDbqwvFblreHp_zEQCAV1IMQOip2dX8d8k"
gmaps = googlemaps.Client(key=google_maps_key)

# %%
# 좌표 입력할 경우 
reverse_geocode_result = gmaps.reverse_geocode((37.5563261606, 126.7690800105), language= "ko") # 좌표 입력
print(type(reverse_geocode_result))
print(reverse_geocode_result)
# Out:
# <class 'list'>
# ...

# %%
reverse_geocode_result[1] # 두 번째 건물 위치표시
# Out:
# {'address_components': [{'long_name': '６４６−４',
#    'short_name': '６４６−４',
#    'types': ['premise']},
#   {'long_name': '오곡동',
#    'short_name': '오곡동',
#    'types': ['political', 'sublocality', 'sublocality_level_2']},
#   {'long_name': '강서구',
#    'short_name': '강서구',
#    'types': ['political', 'sublocality', 'sublocality_level_1']},
#   {'long_name': '서울특별시',
#    'short_name': '서울특별시',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': '대한민국', 'short_name': 'KR', 'types': ['country', 'political']},
#   {'long_name': '157-260', 'short_name': '157-260', 'types': ['postal_code']}],
#  'formatted_address': '대한민국 서울특별시 강서구 오곡동 646-4',
#  'geometry': {'location': {'lat': 37.5564353, 'lng': 126.7690758},
#   'location_type': 'ROOFTOP',
#   'viewport': {'northeast': {'lat': 37.5577842802915,
#     'lng': 126.7704247802915},
#    'southwest': {'lat': 37.5550863197085, 'lng': 126.7677268197085}}},
#  'place_id': 'ChIJrYjgrdmCfDURfZQFQOcNUVU',
# ...

# %%
reverse_geocode_result[1]["formatted_address"] # 보통 formatted_address가 시군구 + 동 표시해 주었습니다.
# Out:
# '대한민국 서울특별시 강서구 오곡동 646-4'

# %%
a = pd.DataFrame(columns=["정류소명", "주소"])

# %%
a=[]

# %%
bus
# Out:
#           표준ID  ARS-ID            정류소명         X좌표        Y좌표
# 0    115000001   16001      염창역.서울도시가스  126.875883  37.547074
# 1    115000002   16002      염창역.서울도시가스  126.875057  37.546863
# 2    115000003   16003       등촌역.강서보건소  126.868670  37.549024
# 3    115000004   16004       등촌역.강서보건소  126.867608  37.549420
# 4    115000005   16005    등촌중학교 백석초등학교  126.861542  37.552610
# ..         ...     ...             ...         ...        ...
# 595  115000571   16993  김포공항세관.국립항공박물관  126.808323  37.555855
# 596  115900146   16994            강원슈퍼  126.857010  37.535532
# 597  115000568   16995          대한항공빌딩  126.814586  37.550747
# 598  115000563   16996            대한항공  126.816540  37.549599
# 599  115000562   16997         김포공항국제선  126.800904  37.564814
#
# [600 rows x 5 columns]

# %%
# 예시
for z in range(len(bus)):
    reverse_geocode_result = gmaps.reverse_geocode((bus["Y좌표"][z], bus["X좌표"][z]), language= "ko")
    for i in range(len(reverse_geocode_result)):
        if "동" in reverse_geocode_result[i]["formatted_address"]:
            a.append(reverse_geocode_result[i]["formatted_address"])

# %%
# 예시
for z in range(len(bus)):
    reverse_geocode_result = gmaps.reverse_geocode((bus["Y좌표"][z], bus["X좌표"][z]), language= "ko")
    a.append(reverse_geocode_result[4]["formatted_address"])

# %%
# 중복된 데이터 제거하기
my_list = a
new_list = []
for v in my_list:
    if v not in new_list:
        new_list.append(v)
len(new_list)
# Out:
# 684

# %%
new_list
# Out:
# ['대한민국 서울특별시 강서구 염창동 282-36',
#  '대한민국 서울특별시 강서구 염창동',
#  '대한민국 서울특별시 양천구 목2동 566',
#  '대한민국 서울특별시 염창동 염창',
#  '대한민국 서울특별시 양천구 목2동',
#  '대한민국 서울특별시 양천구 목동',
#  '대한민국 서울특별시 양천구 목동 602-18',
#  '대한민국 서울특별시 양천구 목3동',
#  '대한민국 서울특별시 강서구 등촌동 533-21',
#  '대한민국 서울특별시 강서구 등촌동 649-2',
#  '대한민국 서울특별시 강서구 등촌2동',
#  '대한민국 서울특별시 강서구 등촌동',
#  '대한민국 서울특별시 강서구 등촌동 607-7',
#  '대한민국 서울특별시 강서구 등촌1동',
#  '대한민국 서울특별시 강서구 등촌1동 655-37',
#  '대한민국 서울특별시 강서구 화곡6동',
#  '대한민국 서울특별시 강서구 화곡동',
#  '대한민국 서울특별시 강서구 등촌동 657-5',
#  '대한민국 서울특별시 강서구 등촌3동',
#  '대한민국 서울특별시 강서구 등촌동 660-6',
#  '대한민국 서울특별시 강서구 등촌3동 공항대로 341',
#  '대한민국 서울특별시 강서구 등촌3동 675-7',
#  '대한민국 서울특별시 강서구 등촌3동 673-4',
#  '대한민국 서울특별시 강서구 공항동 50-6',
#  '대한민국 서울특별시 강서구 공항동',
#  '대한민국 서울특별시 강서구 공항동 22-187',
#  '대한민국 서울특별시 강서구 공항동 산12-5',
#  '대한민국 서울특별시 강서구 내발산동 727-14',
#  '대한민국 서울특별시 강서구 내발산동',
#  '대한민국 서울특별시 강서구 가양1동 517',
#  '대한민국 서울특별시 강서구 가양동',
#  '대한민국 서울특별시 강서구 가양1동',
#  '대한민국 서울특별시 가양1동 마곡역',
#  '대한민국 서울특별시 강서구 가양1동 527',
# ...
