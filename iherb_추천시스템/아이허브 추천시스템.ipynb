# %% [markdown]
# # 1. 아이허브 웹크롤링

# %%
import sys # 시스템
import os  # 시스템

import pandas as pd  # 판다스 : 데이터분석 라이브러리
import numpy as np   # 넘파이 : 숫자, 행렬 데이터 라이브러리

from selenium import webdriver   # 웹 브라우저 자동화
from selenium.webdriver.common.keys import Keys
import chromedriver_autoinstaller
import time    # 서버와 통신할 때 중간중간 시간 지연. 보통은 1초
from tqdm import tqdm_notebook   # for문 돌릴 때 진행상황을 %게이지로 알려준다.

# 워닝 무시
import warnings
warnings.filterwarnings('ignore')

# %%
# Step 1. 크롬 웹브라우저 실행

# pip install chromedriver_autoinstaller
chrome_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(chrome_path)

# iherb
driver.get('https://kr.iherb.com/c/mct-oil')
time.sleep(2)  # 2초간 정지

# 제품 url들 수집
url_list = []
name_list = []
num_list =[]

try:
    for j in range(0,3):
        for i in range(0,24):


                    # URL_raw 크롤링 시작
            items = ".absolute-link-wrapper > a"
            item_raw = driver.find_elements_by_css_selector(items)

            # url 크롤링    
            url = item_raw[i].get_attribute('href')
            url_list.append(url)

            # 상품번호 크롤링
            num = item_raw[i].get_attribute('data-product-id')
            num_list.append(num)
            # 제목 크롤링 
            name = item_raw[i].get_attribute('title')
            name_list.append(name)
            time.sleep(2)
            
            if i % 24 == 23:
                pg_nx= driver.find_element_by_css_selector(".pagination-next")
                driver.execute_script("arguments[0].click();", pg_nx)
                time.sleep(2)
except:
    driver.close()

# %%
df = pd.DataFrame({'url':url_list, 'name':name_list, 'item_id':num_list})
# 저장하기
df.to_excel("iherb_mctoil.xlsx", encoding='utf-8-sig')
# df.to_csv("blog_url.csv")

# %%
df=df.iloc[:57]
df
# Out:
#                                                   url  \
# 0   https://kr.iherb.com/pr/california-gold-nutrit...
# 1   https://kr.iherb.com/pr/california-gold-nutrit...
# 2   https://kr.iherb.com/pr/nature-s-way-organic-m...
# 3   https://kr.iherb.com/pr/now-foods-caprylic-aci...
# 4   https://kr.iherb.com/pr/sports-research-organi...
# 5   https://kr.iherb.com/pr/nature-s-way-organic-m...
# 6   https://kr.iherb.com/pr/now-foods-sports-mct-o...
# 7   https://kr.iherb.com/pr/now-foods-sports-mct-o...
# 8   https://kr.iherb.com/pr/sports-research-mct-oi...
# 9   https://kr.iherb.com/pr/jarrow-formulas-mct-oi...
# 10  https://kr.iherb.com/pr/sports-research-mct-oi...
# 11  https://kr.iherb.com/pr/garden-of-life-dr-form...
# 12  https://kr.iherb.com/pr/sports-research-mct-oi...
# 13  https://kr.iherb.com/pr/carlson-labs-mct-omega...
# 14  https://kr.iherb.com/pr/bulletproof-mct-oil-16...
# 15  https://kr.iherb.com/pr/nature-s-way-mct-oil-1...
# 16  https://kr.iherb.com/pr/garden-of-life-dr-form...
# 17  https://kr.iherb.com/pr/sports-research-organi...
# 18  https://kr.iherb.com/pr/sports-research-organi...
# 19  https://kr.iherb.com/pr/garden-of-life-dr-form...
# 20  https://kr.iherb.com/pr/superfat-keto-nut-butt...
# 21  https://kr.iherb.com/pr/garden-of-life-dr-form...
# 22  https://kr.iherb.com/pr/nutiva-organic-mct-oil...
# 23  https://kr.iherb.com/pr/dr-mercola-mitomix-ket...
# 24  https://kr.iherb.com/pr/rapidfire-collagen-cre...
# 25  https://kr.iherb.com/pr/now-foods-sports-organ...
# 12        Sports Research, MCT 오일, 1,000mg, 소프트젤 120정   75244
# 13        Carlson Labs, MCT & 오메가-3, 120 + 30 추가 소프트젤   71877
# 14             BulletProof, XCT 오일, 16 fl oz (473 ml)   78309
# 15                 Nature's Way, 중쇄중성지방 오일, 소프트젤 180정   81328
# 16  Garden of Life, Dr. Formulated 두뇌 건강, 100% 유기농...   79830
# 17  Sports Research, 유기농 중쇄중성지방 오일 가루, 무맛, 300g(10...   84970
# 18    Sports Research, 유기농 MCT 오일, 무맛, 946ml(32fl oz)   79969
# 19  Garden of Life, 닥터 포뮬레이티드 두뇌 건강, 100% 유기농 코코넛 ...   79831
# 20  SuperFat, Keto Nut Butter, Macadamia MCT + Pro...  111540
# 21  Garden of Life, 의사가 제조한 케토, 유기농 목초 사육 버터 파우더, ...   86685
# 22    Nutiva, 100% 유기농 코코넛 MCT 오일, 무맛, 473ml(16fl oz)   76228
# 23        Dr. Mercola, Mitomix 케톤 에너지, 473ml(16fl oz)   73793
# 24            RAPIDFIRE, 콜라겐 크리머, 천연향료, 214.2g(7.6oz)   97664
# 25       NOW Foods, 스포츠, 유기농 MCT 오일, 32 fl oz (946mL)   86757
# 26          RAPIDFIRE, 터보 크리머, 프렌치 바닐라 향, 250g(8.8oz)   97666
# 27  NOW Foods, Sports, MCT Oil, Vanilla Hazelnut, ...   69740
# 28             Nutiva, 유기농 MCT 분말, 초콜릿, 10.6 oz(300g)   89351
# 29  Purely Inspired, 100% Pure MCT Oil, 16 fl oz (...  102362
# 30  RSP Nutrition, Clean Active Nutrition, 중쇄중성지방 ...   86431
# 31  Carlson Labs, MCT & 오메가-3, 천연 레몬 라임, 200ml(6.7...   90179
# 32                  Onnit, MCT 오일, 무맛, 709ml(24fl oz)   84071
# 33  NOW Foods, 스포츠, MCT 오일, 초콜릿 모카, 16 fl oz (473 ml)   72622
# 34       Kiss My Keto, MCT Oil Softgels, 300 Softgels  106312
# 35  Dr. Mercola, Mitomix, Keto Creamer with Coconu...   98641
# 36  BPI Sports, Keto Bomb, 케토 커피 크리머, 프렌치 바닐라 라떼, ...   73478
# 37  Onnit, 유화 MCT 오일, 비유제품 크리머, 크리미 바닐라, 473ml(16f...   84072
# 38  Dr. Mercola, Mitomix, Keto Creamer with Grass ...   98642
# 39  NuNaturals, MCT Oil Powder, Unflavored, 1 lb (...  112131
# 40    Nutiva, 100% 유기농 코코넛 MCT 오일, 무맛, 946ml(32fl oz)   76229
# 41  Protocol for Life Balance, 퓨어 MCT 오일, 32 fl oz...   81748
# 42  Vitamin Bounty, Stay In Keto, Fractioned MCT P...  104530
# 43          DietWorks, MCT Oil, 1,000 mg, 90 Softgels  106395
# 44  Country Farms, MCT Oil, 100% Coconut Source, 1...  102617
# 45  Coromega, Max Ketogenic MCT Energy, Chocolate ...  105319
# 46  Buried Treasure, 리퀴드 뉴트리언츠, 코코넛 오일, 16 액량 온스 (...   45436
# 47            Nutiva, 유기농 중쇄중성지방 분말, 무맛, 300g(10.6oz)   82001
# 48  Buried Treasure, 리퀴드 뉴트리언츠, 코코넛 오일, 16 액량 온스 (...   45436
# 49    Julian Bakery, KetoThin C8 Fuel, 473ml(16fl oz)   82529
# 50         Quest Nutrition, MCT 오일 파우더, 16 oz (454 g)   82828
# 51           Nutiva, 유기농 중쇄중성지방 분말, 바닐라, 300g(10.6oz)   89350
# 52  NOW Foods, Sports, 유청 단백질 함유 MCT 분말, 무맛, 454g(...  100197
# 53  NOW Foods, Sports, MCT Powder with Whey Protei...  100545
# 54  Jarrow Formulas, 유기농 중쇄중성지방 오일, 무맛, 473ml(16fl...  104456
# 55  NOW Foods, Sports, Keto Protein with MCT Powde...  101877
# 56  Zhou Nutrition, MCT 파우더 위드 프리바이오틱 파이버 , 14.5 o...   81767

# %% [markdown]
# ## 1.2 유저리뷰 크롤링

# %%
# "url_list.csv" 불러오기
url_load = pd.read_excel("iherb_mctoil.xlsx")
url_load = url_load.drop("Unnamed: 0", axis=1)  # 불필요한 칼럼 삭제

url = url_load['url'][0]
chrome_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(chrome_path)

driver.get(url)   # 글 띄우기
time.sleep(1)

# %%
dict = {}    # 전체 크롤링 데이터를 담을 그릇

# 수집할 글 갯수 정하기
number = 30

# 수집한 url 돌면서 데이터 수집
for i in tqdm_notebook(range(0, number)):
    # 글 띄우기
    url = url_list[i]
    chrome_path = chromedriver_autoinstaller.install()
    driver = webdriver.Chrome(chrome_path)

    driver.get(url)   # 글 띄우기
    time.sleep(2)
    
    #리뷰창 들어가기
    review =driver.find_element_by_key("모든 구매후기 보기")
    review.click()
    
    # 크롤링
    
    try : 
        
        target_info = {}  # 개별 블로그 내용을 담을 딕셔너리 생성


        # 리뷰 크롤링
        user id = ".se-component.se-text.se-l-default"                                 
        contents = driver.find_elements_by_css_selector(overlays)    # contents

        content_list = []
        for content in contents:
            content_list.append(content.text)
 
        content_str = ' '.join(content_list)                         # content_str

        # 글 하나는 target_info라는 딕셔너리에 담기게 되고,
        target_info['title'] = title
        target_info['nickname'] = nickname
        target_info['datetime'] = datetime
        target_info['content'] = content_str

        # 각각의 글은 dict라는 딕셔너리에 담기게 됩니다.
        dict[i] = target_info
        time.sleep(1)
        
        # 크롤링이 성공하면 글 제목을 출력하게 되고,
        print(i, title)

        # 글 하나 크롤링 후 크롬 창을 닫습니다.
        driver.close()       
    
    # 에러나면 현재 크롬창을 닫고 다음 글(i+1)로 이동합니다.
    except:
        driver.close()
        time.sleep(1)
        continue
    
    # 중간,중간에 파일로 저장하기ii
    if i == 30 or 50 or 80:
        # 판다스로 만들기
        import pandas as pd
        result_df = pd.DataFrame.from_dict(dict, 'index')

        # 저장하기
        result_df.to_excel("blog_content.xlsx", encoding='utf-8-sig')
        time.sleep(3)

print('수집한 글 갯수: ', len(dict))
print(dict)

# %% [markdown]
# # 2. 데이터 전처리

# %% [markdown]
# # 3. 추천시스템

# %% [markdown]
# # 4. 평가/검증
